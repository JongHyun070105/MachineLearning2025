# %% [markdown]
# <a href="https://colab.research.google.com/github/JongHyun070105/MachineLearning2025/blob/main/3710%EB%B0%95%EC%A2%85%ED%98%84_Chapter2__%EB%8D%B0%EC%9D%B4%ED%84%B0_%ED%9A%8D%EB%93%9D%ED%95%98%EA%B8%B0(%EC%8B%A4%EC%8A%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####1.넘파이(Numpy) 데이터 만들기
# ####[1, 2, 3, 4, 5]

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# ####2.넘파이(Numpy) 데이터 만들기
# ####['대한민국', '포르투칼', '가나', '우루과이']

# %%
np.array(['대한민국','포르투칼','가나','우루과이'])
# Out:
# array(['대한민국', '포르투칼', '가나', '우루과이'], dtype='<U4')

# %% [markdown]
# ####3.넘파이(Numpy) 데이터 만들기
# ####[1,2,'대한민국', '포르투칼']

# %%
np.array([1,2,'대한민국','포르투칼'])
# Out:
# array(['1', '2', '대한민국', '포르투칼'], dtype='<U21')

# %% [markdown]
# ####4.판다스 Series생성하기
# ## ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
a = pd.Series(['대한민국','포르투칼','가나','우르과이'],index = ['가','나','다','라'])
print(a)
# Out:
# 가    대한민국
# 나    포르투칼
# 다      가나
# 라    우르과이
# dtype: object

# %% [markdown]
# ####5.딕셔너리(Dictionary)형으로 데이터프레임(DataFrame) 생성하기
# ## ![image.png](data:image/png;base64,...)

# %%
data = {
  'a' : (1,2,3),
  'b' : (4,5,6),
  'c' : (7,8,9)
}
data
pd.DataFrame(data)
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# ####6. 리스트(LIST)형으로 데이터프레임(DataFrame)생성하기
# ![image.png](data:image/png;base64,...)

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]
index = ['a','b','c']

pd.DataFrame(data, index = index)
# Out:
#    0  1  2
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %% [markdown]
# ###6. clean_Dataset.csv 파일을 읽어 데이터 프레임 생성하기
# ##데이터프레임 이름 : flight

# %%
flight = pd.read_csv('./Clean_Dataset.csv')
pd.DataFrame(flight)
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %% [markdown]
# ###8. 데이터프레임 생성하기
# 데이터프레임 이름  : a2
# ## ![image.png](data:image/png;base64,...)

# %%
a2 = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],index=['a','b','c'])
a2
# Out:
#    0  1  2
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %% [markdown]
# ###9. a2를 csv 파일에 저장하기
# ### 파일명: result_a2.csv

# %%
a2.to_csv('result_a2.csv')

# %% [markdown]
# ###clean_Dataset.csv 파일에서 원하는 컬럼만 가지고 데이터프레임 생성하기
# ![image.png](data:image/png;base64,...)

# %%
data = pd.read_csv('./Clean_Dataset.csv')
df = pd.DataFrame(data)

b = df[['departure_time','arrival_time','destination_city']]
b.set_index(df['stops'],inplace=True)
b
# Out:
#       departure_time   arrival_time destination_city
# stops
# zero         Evening          Night           Mumbai
# zero   Early_Morning        Morning           Mumbai
# zero   Early_Morning  Early_Morning           Mumbai
# zero         Morning      Afternoon           Mumbai
# zero         Morning        Morning           Mumbai
# ...              ...            ...              ...
# one          Morning        Evening        Hyderabad
# one        Afternoon          Night        Hyderabad
# one    Early_Morning          Night        Hyderabad
# one    Early_Morning        Evening        Hyderabad
# one          Morning        Evening        Hyderabad
#
# [300153 rows x 3 columns]

# %% [markdown]
# ##[확인문제01] 구글이 제공하는 클라우드 기반의 주피터 노트북 환경은 무엇인가요?
# ##① 파이썬
# ##② 코랩
# ##③ 아나콘다
# ##④ 깃허브

# %% [markdown]
# 2번

# %% [markdown]
# ##[확인문제02] 일반 텍스트 기반의 경량 마크업 언어로, HTML과 리치 텍스트(RTF) 등 서식 문서로 쉽게 변환되기 때문에 응용 소프트웨어와 함께 배포되는 readme 파일이나 온라인 게시물등에 많이 사용되는 언어는 무엇인가요?
# ##① 마크다운
# ##② CSS
# ##③ 텍스트
# ##④ 자바

# %% [markdown]
# 1번

# %% [markdown]
# ##[확인문제03] 다음 문법에서 오류를 수정하여 코드를 다시 작성하시오.
# #![image.png](data:image/png;base64,...)

# %%
new_df = pd.DataFrame([[1,2,3],[2,3,4],[4,5,6]],['r1','r2','r3'])
new_df
# Out:
#     0  1  2
# r1  1  2  3
# r2  2  3  4
# r3  4  5  6

# %% [markdown]
# ##[확인문제04] 판다스에서 사용되는 자료구조 중 2차원 형태로 데이터 분석에 가장 많이 사용되는 것은 무엇인가?
# ##① Series
# ##② Python
# ##③ Numpy
# ##④ DataFrame

# %% [markdown]
# Series

# %% [markdown]
# 참고문헌
# https://pandas.pydata.org/docs/reference/api/pandas.Series.name.html
# https://aplab.tistory.com/entry/%EB%A6%AC%EC%8A%A4%ED%8A%B8-%ED%8C%90%EB%8B%A4%EC%8A%A4-%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84#google_vignette
