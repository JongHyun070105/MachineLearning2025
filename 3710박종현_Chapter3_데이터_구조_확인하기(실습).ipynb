# %% [markdown]
# <a href="https://colab.research.google.com/github/JongHyun070105/MachineLearning2025/blob/main/3710%EB%B0%95%EC%A2%85%ED%98%84_Chapter3_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EA%B5%AC%EC%A1%B0_%ED%99%95%EC%9D%B8%ED%95%98%EA%B8%B0(%EC%8B%A4%EC%8A%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SECTION 01. 데이터프레임 확인하기

# %% [markdown]
# ## 1. 데이터 살펴보기

# %%
# 넘파이(Numpy), 판다스(Pandas) 불러오기
import numpy as np
import pandas as pd

# read_csv 함수로 "Clean_Dataset.csv" 불러와서 데이터프레임 생성하기（flight）

flight = pd.DataFrame(pd.read_csv('./Clean_Dataset.csv'))

# %%
# head 확인하기
flight.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left   price
# 0          Night           Mumbai  Economy      2.17        1.0  5953.0
# 1        Morning           Mumbai  Economy      2.33        1.0  5953.0
# 2  Early_Morning           Mumbai  Economy      2.17        1.0  5956.0
# 3      Afternoon           Mumbai  Economy      2.25        1.0  5955.0
# 4        Morning           Mumbai  Economy      2.33        1.0  5955.0

# %%
# tail 확인하기
flight.tail()
# Out:
#         Unnamed: 0    airline   flight source_city departure_time stops  \
# 154689      154689     Indigo  6E-6684   Hyderabad          Night  zero
# 154690      154690     Indigo  6E-2349   Hyderabad          Night  zero
# 154691      154691  Air_India   AI-559   Hyderabad  Early_Morning  zero
# 154692      154692     Indigo  6E-2248   Hyderabad      Afternoon  zero
# 154693      154693     Indigo   6E-643        Hyde            NaN   NaN
#
#        arrival_time destination_city    class  duration  days_left   price
# 154689        Night            Delhi  Economy      2.25       21.0  2694.0
# 154690   Late_Night            Delhi  Economy      2.25       21.0  2694.0
# 154691      Morning            Delhi  Economy      2.50       21.0  2696.0
# 154692      Evening            Delhi  Economy      2.25       21.0  3191.0
# 154693          NaN              NaN      NaN       NaN        NaN     NaN

# %%
# head로 상위 10개의 데이터 확인하기
flight.head(10)
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
# 5           5   Vistara   UK-945       Delhi        Morning  zero
# 6           6   Vistara   UK-927       Delhi        Morning  zero
# 7           7   Vistara   UK-951       Delhi      Afternoon  zero
# 8           8  GO_FIRST   G8-334       Delhi  Early_Morning  zero
# 9           9  GO_FIRST   G8-336       Delhi      Afternoon  zero
#
#     arrival_time destination_city    class  duration  days_left   price
# 0          Night           Mumbai  Economy      2.17        1.0  5953.0
# 1        Morning           Mumbai  Economy      2.33        1.0  5953.0
# ...

# %%
# tail로 하위 3개의 데이터 확인하기
flight.tail(3)
# Out:
#         Unnamed: 0    airline   flight source_city departure_time stops  \
# 154691      154691  Air_India   AI-559   Hyderabad  Early_Morning  zero
# 154692      154692     Indigo  6E-2248   Hyderabad      Afternoon  zero
# 154693      154693     Indigo   6E-643        Hyde            NaN   NaN
#
#        arrival_time destination_city    class  duration  days_left   price
# 154691      Morning            Delhi  Economy      2.50       21.0  2696.0
# 154692      Evening            Delhi  Economy      2.25       21.0  3191.0
# 154693          NaN              NaN      NaN       NaN        NaN     NaN

# %% [markdown]
# ## 2. 데이터프레임의 기본 정보 확인하기

# %%
# shape 확인하기
flight.shape
# Out:
# (154694, 12)

# %%
# columns 확인하기
flight.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')

# %%
# info 확인하기
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154694 entries, 0 to 154693
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        154694 non-null  int64
#  1   airline           154694 non-null  object
#  2   flight            154694 non-null  object
#  3   source_city       154694 non-null  object
#  4   departure_time    154693 non-null  object
#  5   stops             154693 non-null  object
#  6   arrival_time      154693 non-null  object
#  7   destination_city  154693 non-null  object
#  8   class             154693 non-null  object
#  9   duration          154693 non-null  float64
#  10  days_left         154693 non-null  float64
#  11  price             154693 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 14.2+ MB

# %%
# describe 확인하기
flight.describe()
# Out:
#           Unnamed: 0       duration      days_left          price
# count  154694.000000  154693.000000  154693.000000  154693.000000
# mean    77346.500000      11.441905      25.837601    6653.731126
# std     44656.455608       7.189235      13.598466    3703.761597
# min         0.000000       0.830000       1.000000    1603.000000
# 25%     38673.250000       6.170000      14.000000    4190.000000
# 50%     77346.500000      10.170000      26.000000    5939.000000
# 75%    116019.750000      15.170000      38.000000    7813.000000
# max    154693.000000      47.750000      49.000000   40354.000000

# %%
# dtypes 확인하기
flight.dtypes
# Out:
# Unnamed: 0            int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left           float64
# price               float64
# dtype: object

# %%
# value_counts 확인하기
flight.value_counts()
# Out:
# Unnamed: 0  airline   flight   source_city  departure_time  stops  arrival_time   destination_city  class    duration  days_left  price
# 154692      Indigo    6E-2248  Hyderabad    Afternoon       zero   Evening        Delhi             Economy  2.25      21.0       3191.0    1
# 0           SpiceJet  SG-8709  Delhi        Evening         zero   Night          Mumbai            Economy  2.17      1.0        5953.0    1
# 1           SpiceJet  SG-8157  Delhi        Early_Morning   zero   Morning        Mumbai            Economy  2.33      1.0        5953.0    1
# 2           AirAsia   I5-764   Delhi        Early_Morning   zero   Early_Morning  Mumbai            Economy  2.17      1.0        5956.0    1
# 3           Vistara   UK-995   Delhi        Morning         zero   Afternoon      Mumbai            Economy  2.25      1.0        5955.0    1
# ...

# %% [markdown]
# ##[확인문제01] 데이터프레임에서 컬럼의 수와 데이터 유형, 결측치 등을 한번에 확인할 수 있는 기본 함수는 무엇인가요?
# ##① info
# ##② dtype
# ##③ shape
# ##④ describe

# %% [markdown]
# info

# %% [markdown]
# ##[확인문제02] 다음 문법은 데이터를 불러온 후 상위 5줄의 데이터를 확인하는 코드 입니다. 다음 문법에서 빈 칸에 들어갈 내용은 무엇인가요?
# ## ![image.png](data:image/png;base64,...)
# ## ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3

# %% [markdown]
# ##[확인문제03] 데이터프레임에서 데이터 타입(형태)확인하는 기본함수는 무엇인가요?
# ##① tuple
# ##② shape
# ##③ columns
# ##④ dtypes

# %% [markdown]
# shape
