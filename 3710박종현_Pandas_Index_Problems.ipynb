# %% [markdown]
# <a href="https://colab.research.google.com/github/JongHyun070105/MachineLearning2025/blob/main/3710%EB%B0%95%EC%A2%85%ED%98%84_Pandas_Index_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Index 실습 문제
#
# 아래 문제를 풀어보세요!

# %%
# 딕셔너리 생성
data1 = {
    '이름': ['철수', '영희', '민수', '지수', '현우', '수빈', '도현', '나연', '지훈', '윤아'],
    '나이': [20, 22, 21, 23, 24, 20, 22, 21, 23, 22],
    '성별': ['남', '여', '남', '여', '남', '여', '남', '여', '남', '여'],
    '거주지': ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '서울', '부산', '대구'],
    '학점': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B', 'A', 'B'],
    '전공': ['컴퓨터공학', '경영학', '경제학', '심리학', '법학', '의학', '사회학', '교육학', '화학', '영문학']
}


data1
# Out:
# {'이름': ['철수', '영희', '민수', '지수', '현우', '수빈', '도현', '나연', '지훈', '윤아'],
#  '나이': [20, 22, 21, 23, 24, 20, 22, 21, 23, 22],
#  '성별': ['남', '여', '남', '여', '남', '여', '남', '여', '남', '여'],
#  '거주지': ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '서울', '부산', '대구'],
#  '학점': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B', 'A', 'B'],
#  '전공': ['컴퓨터공학', '경영학', '경제학', '심리학', '법학', '의학', '사회학', '교육학', '화학', '영문학']}

# %%
#리스트생성
data2= [
    ['철수', 20, '남', '서울', 'A', '컴퓨터공학'],
    ['영희', 22, '여', '부산', 'B', '경영학'],
    ['민수', 21, '남', '대구', 'A', '경제학'],
    ['지수', 23, '여', '인천', 'C', '심리학'],
    ['현우', 24, '남', '광주', 'B', '법학'],
    ['수빈', 20, '여', '대전', 'A', '의학'],
    ['도현', 22, '남', '울산', 'C', '사회학'],
    ['나연', 21, '여', '서울', 'B', '교육학'],
    ['지훈', 23, '남', '부산', 'A', '화학'],
    ['윤아', 22, '여', '대구', 'B', '영문학']
]
data2
# Out:
# [['철수', 20, '남', '서울', 'A', '컴퓨터공학'],
#  ['영희', 22, '여', '부산', 'B', '경영학'],
#  ['민수', 21, '남', '대구', 'A', '경제학'],
#  ['지수', 23, '여', '인천', 'C', '심리학'],
#  ['현우', 24, '남', '광주', 'B', '법학'],
#  ['수빈', 20, '여', '대전', 'A', '의학'],
#  ['도현', 22, '남', '울산', 'C', '사회학'],
#  ['나연', 21, '여', '서울', 'B', '교육학'],
#  ['지훈', 23, '남', '부산', 'A', '화학'],
#  ['윤아', 22, '여', '대구', 'B', '영문학']]

# %% [markdown]
# ## 문제 1
# 1. 딕셔너리를 사용하여 DataFrame을 생성하세요.
#    - 제공된 `data1`을 사용하세요.

# %%
import pandas as pd
df = pd.DataFrame(data1)
df
# Out:
#    이름  나이 성별 거주지 학점     전공
# 0  철수  20  남  서울  A  컴퓨터공학
# 1  영희  22  여  부산  B    경영학
# 2  민수  21  남  대구  A    경제학
# 3  지수  23  여  인천  C    심리학
# 4  현우  24  남  광주  B     법학
# 5  수빈  20  여  대전  A     의학
# 6  도현  22  남  울산  C    사회학
# 7  나연  21  여  서울  B    교육학
# 8  지훈  23  남  부산  A     화학
# 9  윤아  22  여  대구  B    영문학

# %% [markdown]
# ## 문제 2
# 2. 리스트를 사용하여 DataFrame을 생성하세요.
#    - 제공된 `data2`를 사용하세요.

# %%
df2 = pd.DataFrame(data2)
df2
# Out:
#     0   1  2   3  4      5
# 0  철수  20  남  서울  A  컴퓨터공학
# 1  영희  22  여  부산  B    경영학
# 2  민수  21  남  대구  A    경제학
# 3  지수  23  여  인천  C    심리학
# 4  현우  24  남  광주  B     법학
# 5  수빈  20  여  대전  A     의학
# 6  도현  22  남  울산  C    사회학
# 7  나연  21  여  서울  B    교육학
# 8  지훈  23  남  부산  A     화학
# 9  윤아  22  여  대구  B    영문학

# %% [markdown]
# ## 문제 3
# 3. 생성한 DataFrame의 인덱스를 확인하세요.
#    - `df.index`를 사용하여 출력하세요.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# ## 문제 4
# 4. 생성한 DataFrame의 인덱스 이름을 '학생번호'로 설정하세요.

# %%
df.index.name = '학생번호'
df
# Out:
#       이름  나이 성별 거주지 학점     전공
# 학생번호
# 0     철수  20  남  서울  A  컴퓨터공학
# 1     영희  22  여  부산  B    경영학
# 2     민수  21  남  대구  A    경제학
# 3     지수  23  여  인천  C    심리학
# 4     현우  24  남  광주  B     법학
# 5     수빈  20  여  대전  A     의학
# 6     도현  22  남  울산  C    사회학
# 7     나연  21  여  서울  B    교육학
# 8     지훈  23  남  부산  A     화학
# 9     윤아  22  여  대구  B    영문학

# %% [markdown]
# ## 문제 5
# 5. 기존 인덱스를 제거하고 기본 숫자 인덱스로 초기화하세요.

# %%
df.reset_index(drop=True,inplace = True)
df
# Out:
#    이름  나이 성별 거주지 학점     전공
# 0  철수  20  남  서울  A  컴퓨터공학
# 1  영희  22  여  부산  B    경영학
# 2  민수  21  남  대구  A    경제학
# 3  지수  23  여  인천  C    심리학
# 4  현우  24  남  광주  B     법학
# 5  수빈  20  여  대전  A     의학
# 6  도현  22  남  울산  C    사회학
# 7  나연  21  여  서울  B    교육학
# 8  지훈  23  남  부산  A     화학
# 9  윤아  22  여  대구  B    영문학

# %% [markdown]
# ## 문제 6
# 6. '이름' 열을 인덱스로 설정하세요.

# %%
df.set_index('이름',inplace = True)
df
# Out:
#     나이 성별 거주지 학점     전공
# 이름
# 철수  20  남  서울  A  컴퓨터공학
# 영희  22  여  부산  B    경영학
# 민수  21  남  대구  A    경제학
# 지수  23  여  인천  C    심리학
# 현우  24  남  광주  B     법학
# 수빈  20  여  대전  A     의학
# 도현  22  남  울산  C    사회학
# 나연  21  여  서울  B    교육학
# 지훈  23  남  부산  A     화학
# 윤아  22  여  대구  B    영문학

# %% [markdown]
# ## 문제 7
# 7. 인덱스를 기준으로 오름차순 정렬하세요.

# %%
df.sort_index(ascending=True)
# Out:
#     나이 성별 거주지 학점     전공
# 이름
# 나연  21  여  서울  B    교육학
# 도현  22  남  울산  C    사회학
# 민수  21  남  대구  A    경제학
# 수빈  20  여  대전  A     의학
# 영희  22  여  부산  B    경영학
# 윤아  22  여  대구  B    영문학
# 지수  23  여  인천  C    심리학
# 지훈  23  남  부산  A     화학
# 철수  20  남  서울  A  컴퓨터공학
# 현우  24  남  광주  B     법학

# %% [markdown]
# ## 문제 8
# 8. 인덱스를 기준으로 내림차순 정렬하세요.

# %%
df.sort_index(ascending=False)
# Out:
#     나이 성별 거주지 학점     전공
# 이름
# 현우  24  남  광주  B     법학
# 철수  20  남  서울  A  컴퓨터공학
# 지훈  23  남  부산  A     화학
# 지수  23  여  인천  C    심리학
# 윤아  22  여  대구  B    영문학
# 영희  22  여  부산  B    경영학
# 수빈  20  여  대전  A     의학
# 민수  21  남  대구  A    경제학
# 도현  22  남  울산  C    사회학
# 나연  21  여  서울  B    교육학

# %% [markdown]
# ## 문제 9
# 9. 인덱스를 유지하면서 '나이' 열을 기준으로 정렬하세요.

# %%
df.sort_values(by='나이')
# Out:
#     나이 성별 거주지 학점     전공
# 이름
# 철수  20  남  서울  A  컴퓨터공학
# 수빈  20  여  대전  A     의학
# 나연  21  여  서울  B    교육학
# 민수  21  남  대구  A    경제학
# 도현  22  남  울산  C    사회학
# 영희  22  여  부산  B    경영학
# 윤아  22  여  대구  B    영문학
# 지수  23  여  인천  C    심리학
# 지훈  23  남  부산  A     화학
# 현우  24  남  광주  B     법학

# %% [markdown]
# ## 문제 10
# 10. 특정 인덱스를 이용하여 행을 선택하세요.
#    - 예: '철수'의 데이터를 선택하세요.

# %%
df.loc['철수']
# Out:
# 나이        20
# 성별         남
# 거주지       서울
# 학점         A
# 전공     컴퓨터공학
# Name: 철수, dtype: object

# %% [markdown]
# ## 문제 11
# 11. 기존 인덱스를 새로운 열로 추가한 후 기본 숫자 인덱스로 변경하세요.

# %%
df.reset_index(inplace = True)
df
# Out:
#    이름  나이 성별 거주지 학점     전공
# 0  철수  20  남  서울  A  컴퓨터공학
# 1  영희  22  여  부산  B    경영학
# 2  민수  21  남  대구  A    경제학
# 3  지수  23  여  인천  C    심리학
# 4  현우  24  남  광주  B     법학
# 5  수빈  20  여  대전  A     의학
# 6  도현  22  남  울산  C    사회학
# 7  나연  21  여  서울  B    교육학
# 8  지훈  23  남  부산  A     화학
# 9  윤아  22  여  대구  B    영문학

# %% [markdown]
# ## 문제 12
# 12. 인덱스를 리셋한 후 '전공' 열을 새로운 인덱스로 설정하세요.

# %%
df.reset_index(inplace = True)
df.set_index('전공',inplace = True)
df
# Out:
#        index  이름  나이 성별 거주지 학점
# 전공
# 컴퓨터공학      0  철수  20  남  서울  A
# 경영학        1  영희  22  여  부산  B
# 경제학        2  민수  21  남  대구  A
# 심리학        3  지수  23  여  인천  C
# 법학         4  현우  24  남  광주  B
# 의학         5  수빈  20  여  대전  A
# 사회학        6  도현  22  남  울산  C
# 교육학        7  나연  21  여  서울  B
# 화학         8  지훈  23  남  부산  A
# 영문학        9  윤아  22  여  대구  B
